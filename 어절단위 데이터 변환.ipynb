# %%
import pandas as pd

label = pd.read_csv('/content/drive/Shared drives/BigData/origin_data/alldata.csv',encoding='utf-8')
data_set = []
for data in label.values.tolist() :
  temp = data[2].split()
  data_set.append(temp)

t = pd.DataFrame(data_set)
print(t)
t.to_csv('/content/drive/Shared drives/BigData/origin_data/token.csv',encoding='utf-8')
# Out:
#                              0                1    ...   258   259
# 0       XXX은행성산XXX팀장입니다.행복한주말되세요             None  ...  None  None
# 1          오늘도많이웃으시는하루시작하세요XXX은행        진월동VIP라운지  ...  None  None
# 2                         안녕하십니까             고객님.  ...  None  None
# 3                            XXX    고객님안녕하세요XXX은행  ...  None  None
# 4                            1월은             새로움이  ...  None  None
# ...                          ...              ...  ...   ...   ...
# 297566                   (광고)XXX  고객님안녕하십니까!!고객님의  ...  None  None
# 297567                       고객님               항상  ...  None  None
# 297568                       XXX              고객님  ...  None  None
# 297569                    (광고)알림             신청하면  ...  None  None
# 297570                      (광고)              XXX  ...  None  None
#
# [297571 rows x 260 columns]
